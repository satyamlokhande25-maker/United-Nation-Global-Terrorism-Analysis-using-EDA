# %% [markdown]
# <a href="https://colab.research.google.com/github/satyamlokhande25-maker/United-Nation-Global-Terrorism-Analysis-using-EDA/blob/main/Exploratory_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# United Nation Global Terrorism Analysis
# Exploratory Data Analysis

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The United Nations Global Terrorism Analysis (UNGTA) project focuses on performing an in-depth exploratory data analysis (EDA) on a comprehensive dataset of global terrorist incidents recorded between 1970 and 2017. Terrorism is a critical global issue that affects national security, economic stability, and public safety. This project aims to analyze historical data to uncover patterns, trends, and meaningful insights that can help in understanding the evolving nature of terrorist activities across the world.
#
# The dataset used in this project is extensive, containing over 180,000 records of terrorist attacks with multiple attributes such as year, country, region, type of attack, responsible group, and the number of casualties. Due to the large size and complexity of the dataset, an initial data preprocessing step is performed. This includes selecting relevant columns, handling missing values, and standardizing inconsistent data entries. For instance, missing values in casualty-related fields are replaced with zeros, and unknown group names are standardized for consistency.
#
# The analysis begins with a detailed exploration of the dataset to understand its structure and key variables. Various exploratory data analysis techniques are applied to identify patterns in terrorist activities. One of the primary analyses involves examining the number of terrorist attacks over time. A line chart is used to visualize trends, revealing that terrorist activities have generally increased over the years, particularly after the early 2000s. This indicates a rising global concern and highlights the importance of continuous monitoring and analysis.
#
# Further analysis is conducted to identify the most affected countries and regions. Bar charts are used to compare the number of attacks across countries and regions, revealing that terrorism is highly concentrated in specific areas rather than being evenly distributed worldwide. The Middle East and North Africa region emerges as the most affected, supporting the hypothesis that certain regions experience higher levels of terrorist activity. This geographical concentration provides valuable insights for policymakers and security agencies.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The objective of this project is to analyze global terrorism data to identify patterns, trends, and key insights. The project focuses on understanding which regions and countries are most affected, how terrorist activities have evolved over time, and whether assumptions such as higher attacks in specific regions and lower casualties in unclaimed attacks are valid.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The United Nations Global Terrorism Analysis dataset provides a detailed record of terrorist incidents worldwide. This analysis helps governments, policymakers, and security agencies understand terrorism patterns, identify high-risk regions, and make informed decisions to improve security and counter-terrorism strategies.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %% [markdown]
# ### Dataset Loading

# %%
df =pd.read_csv('/content/Global Terrorism Data.csv',encoding='latin-1')

# %% [markdown]
# ### Dataset First View

# %%
df.head()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
df.shape

# %% [markdown]
# ### Dataset Information

# %%
df.info()

# %% [markdown]
# #### Duplicate Values

# %%
df.duplicated().sum()

# %% [markdown]
# #### Missing Values/Null Values

# %%
df.isnull().sum()

# %%
df.isnull()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# It is a comprehensive global terrorism dataset (1970–2017) containing detailed information on attacks, including location, type, casualties, and responsible groups.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
df.columns

# %%
df.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# ### Check Unique Values for each variable.

# %% [markdown]
# The dataset consists of multiple variables that describe different aspects of terrorist incidents. The key variables used in this analysis are:
#
# iyear: Represents the year in which the terrorist attack occurred. It helps in analyzing trends over time.
# country_txt: Indicates the name of the country where the attack took place. This is useful for country-wise analysis.
# region_txt: Describes the region of the world (e.g., Middle East & North Africa, South Asia). It helps in regional comparisons.
# attacktype1_txt: Specifies the type of attack carried out, such as bombing, assassination, or armed assault.
# gname: Refers to the name of the terrorist group responsible for the attack. If unknown, it is labeled as "Unknown Group".
# nkill: Represents the number of people killed in the attack. It is used to measure the severity of incidents.
# nwound: Indicates the number of people injured during the attack.
# total_casualties: A derived variable calculated as the sum of killed and wounded (nkill + nwound), representing the total impact of the attack.

# %%
for col in df.columns:
  print(f'{col}:{df[col].unique()}')

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
df = df[['iyear','country_txt','region_txt','attacktype1_txt','gname','nkill','nwound']]

df['nkill'] = df['nkill'].fillna(0)
df['nwound'] = df['nwound'].fillna(0)

df['gname'] = df['gname'].replace("Unknown", "Unknown Group")

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# The dataset was cleaned by selecting relevant columns, handling missing values, and creating a new feature for total casualties. Data was then aggregated by year, country, and region to support visualization.
#
# The insights from the visualizations show that terrorist attacks have increased over time, are highly concentrated in regions like the Middle East & North Africa, and are dominated by a few countries and groups. Additionally, common attack types such as bombings and armed assaults are frequently used, and unknown groups tend to have slightly lower casualties.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
plt.figure()
df['iyear'].value_counts().sort_index().plot()
plt.title("Attacks per Year")
plt.xlabel("Year")
plt.ylabel("Number of Attacks")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line chart is used to show trends over time clearly.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Terrorist attacks have increased significantly over the years, especially after 2000.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, it helps in understanding trends and improving long-term security planning.

# %% [markdown]
# #### Chart - 2

# %%
plt.figure()
df['country_txt'].value_counts().head(10).plot(kind='bar')
plt.title("Top 10 Countries with Most Attacks")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# A bar chart is ideal for comparing values across different categories.Answer Here.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# A few countries account for the majority of terrorist attacks.

# %% [markdown]
# #### Chart - 3

# %%
plt.figure()
df['region_txt'].value_counts().plot(kind='bar')
plt.title("Attacks by Region")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar charts make it easy to compare attack counts across regions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Middle East & North Africa region has the highest number of attacks.Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# yes, it helps in prioritizing resources in high-risk regions.

# %% [markdown]
# #### Chart - 4

# %%
plt.figure()
df['attacktype1_txt'].value_counts().plot(kind='bar')
plt.title("Attack Types Distribution")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar chart helps in comparing frequency of different attack types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Bombings and armed assaults are the most commonly used attack methods.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, it helps in preparing defense strategies against common attack types.

# %% [markdown]
# #### Chart - 5

# %%
text = " ".join(df['gname'])

wc = WordCloud(width=800, height=400).generate(text)

plt.imshow(wc)
plt.axis("off")
plt.title("Most Active Terrorist Groups")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# WordCloud visually highlights the most frequent group names.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# A few terrorist groups appear frequently, indicating their dominance.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, it helps in identifying key groups for targeted counter-terrorism actions.

# %% [markdown]
# #### Chart - 6

# %%
df['total_casualties'] = df['nkill'] + df['nwound']

plt.figure(figsize=(10,5))
df.groupby('iyear')['total_casualties'].sum().plot()
plt.title("Total Casualties Over Years")
plt.xlabel("Year")
plt.ylabel("Casualties")
plt.grid()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line chart is useful to show trends in casualties over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Casualties fluctuate but show peaks during certain years, indicating high-impact events.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, it helps in understanding high-risk periods, but increasing casualties indicate negative societal and economic impact.

# %% [markdown]
# #### Chart - 7

# %%
plt.figure(figsize=(10,5))
df.groupby('region_txt')['total_casualties'].sum().sort_values(ascending=False).head(10).plot(kind='bar')
plt.title("Top Regions by Casualties")
plt.xlabel("Region")
plt.ylabel("Total Casualties")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar chart allows comparison of casualties across regions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Certain regions have significantly higher casualties than others.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, it helps allocate resources effectively, but high casualties indicate severe negative impact on those regions.

# %% [markdown]
# #### Chart - 8

# %%
plt.figure(figsize=(10,5))
df.groupby('country_txt')['total_casualties'].sum().sort_values(ascending=False).head(10).plot(kind='bar')
plt.title("Top Countries by Casualties")
plt.xlabel("Country")
plt.ylabel("Total Casualties")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Bar chart is suitable for comparing casualties across countries.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Certain countries experience significantly higher casualties.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, it helps identify vulnerable countries, but high casualties negatively affect development.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# The analysis provides valuable insights into terrorism patterns, helping stakeholders identify high-risk regions, understand attack trends, and focus on major terrorist groups. These findings support better decision-making in security planning and risk management.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The project successfully analyzed global terrorism data and identified key patterns such as increasing attack trends, regional concentration, and dominant terrorist groups. The insights gained can help governments and organizations improve counter-terrorism strategies and enhance global security.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
